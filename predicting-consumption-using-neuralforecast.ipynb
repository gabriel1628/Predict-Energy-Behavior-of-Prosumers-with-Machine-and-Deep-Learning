# %%
import boto3
import pandas as pd
from sagemaker import get_execution_role

role = get_execution_role()
bucket = 'projet-cobalt'
data_key = 'Enefit/train.csv'
data_location = 's3://{}/{}'.format(bucket, data_key)

## Load and save data

# data = pd.read_csv(data_location)
# data.head()

# consumption = data[data["is_consumption"]==1]
# consumption.to_csv("data/consumption.csv")

# production = data[data["is_consumption"]==0]
# production.to_csv("data/production.csv")
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml

# %% [markdown]
# # Data setup

# %%
df = pd.read_csv(
    "data/consumption.csv", usecols=["prediction_unit_id", "datetime", "target"]
)[["prediction_unit_id", "datetime", "target"]].rename(
    columns={"prediction_unit_id": "unique_id", "datetime": "ds", "target": "y"}
)
df["ds"] = pd.to_datetime(df["ds"])
df.head()
# Out:
#    unique_id         ds        y
# 0          0 2021-09-01   96.590
# 1          1 2021-09-01   17.314
# 2          2 2021-09-01  656.859
# 3          3 2021-09-01   59.000
# 4          4 2021-09-01  501.760

# %% [markdown]
# # Filling NaN values

# %%
df.isna().sum()
# Out:
# unique_id      0
# ds             0
# y            264
# dtype: int64

# %%
df["y"] = df["y"].interpolate(method="linear")
df.isna().sum()
# Out:
# unique_id    0
# ds           0
# y            0
# dtype: int64

# %% [markdown]
# # Train/Test split

# %%
# taking the last 48 hours for test
for i in df["unique_id"].unique():
    if i == df["unique_id"].unique()[0]:
        df_test = df[df["unique_id"]==i][-48:]
        continue
    df_test = pd.concat([df_test, df[df["unique_id"]==i][-48:]])
    
df_test.sort_index(inplace=True)
print(df_test.shape)
df_test.head()
# Out:
# (3312, 3)
#         unique_id                  ds      y
# 906150         26 2023-03-28 00:00:00  5.137
# 906217         26 2023-03-28 01:00:00  4.212
# 906284         26 2023-03-28 02:00:00  4.917
# 906351         26 2023-03-28 03:00:00  4.195
# 906418         26 2023-03-28 04:00:00  4.518

# %%
train_idx = [idx for idx in df.index if idx not in df_test.index]
df_train = df.loc[train_idx]
df_train.shape
df_train.head()
# Out:
#    unique_id         ds        y
# 0          0 2021-09-01   96.590
# 1          1 2021-09-01   17.314
# 2          2 2021-09-01  656.859
# 3          3 2021-09-01   59.000
# 4          4 2021-09-01  501.760

# %%
df.shape[0] == df_train.shape[0] + df_test.shape[0]
# Out:
# True

# %%
df.shape[1] == df_train.shape[1] == df_test.shape[1]
# Out:
# True

# %% [markdown]
# # Installing NeuralForecast

# %%
# !pip install neuralforecast
# Out:
# Collecting neuralforecast
#   Downloading neuralforecast-1.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting coreforecast>=0.0.6 (from neuralforecast)
#   Downloading coreforecast-0.0.7-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: fsspec in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from neuralforecast) (2024.2.0)
# Requirement already satisfied: numpy>=1.21.6 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from neuralforecast) (1.26.4)
# Requirement already satisfied: pandas>=1.3.5 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from neuralforecast) (1.5.3)
# Requirement already satisfied: torch>=2.0.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from neuralforecast) (2.1.0)
# Collecting pytorch-lightning>=2.0.0 (from neuralforecast)
#   Downloading pytorch_lightning-2.2.1-py3-none-any.whl.metadata (21 kB)
# Collecting ray>=2.2.0 (from ray[tune]>=2.2.0->neuralforecast)
#   Downloading ray-2.10.0-cp310-cp310-manylinux2014_x86_64.whl.metadata (13 kB)
# Collecting optuna (from neuralforecast)
#   Downloading optuna-3.6.1-py3-none-any.whl.metadata (17 kB)
# Collecting utilsforecast>=0.0.25 (from neuralforecast)
#   Downloading utilsforecast-0.1.2-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from pandas>=1.3.5->neuralforecast) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from pandas>=1.3.5->neuralforecast) (2024.1)
# Requirement already satisfied: tqdm>=4.57.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from pytorch-lightning>=2.0.0->neuralforecast) (4.66.2)
# Requirement already satisfied: PyYAML>=5.4 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from pytorch-lightning>=2.0.0->neuralforecast) (6.0.1)
# Collecting torchmetrics>=0.7.0 (from pytorch-lightning>=2.0.0->neuralforecast)
#   Downloading torchmetrics-1.3.2-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from pytorch-lightning>=2.0.0->neuralforecast) (21.3)
# Requirement already satisfied: typing-extensions>=4.4.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from pytorch-lightning>=2.0.0->neuralforecast) (4.9.0)
# Collecting lightning-utilities>=0.8.0 (from pytorch-lightning>=2.0.0->neuralforecast)
#   Downloading lightning_utilities-0.11.2-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: click>=7.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast) (8.1.7)
# Requirement already satisfied: filelock in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast) (3.13.1)
# Requirement already satisfied: jsonschema in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast) (4.21.1)
# Collecting msgpack<2.0.0,>=1.0.0 (from ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast)
#   Downloading msgpack-1.0.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.1 kB)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast) (4.25.3)
# Collecting aiosignal (from ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast)
#   Downloading aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting frozenlist (from ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast)
#   Downloading frozenlist-1.4.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: requests in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast) (2.31.0)
# Collecting tensorboardX>=1.9 (from ray[tune]>=2.2.0->neuralforecast)
#   Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: pyarrow>=6.0.1 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from ray[tune]>=2.2.0->neuralforecast) (15.0.0)
# Requirement already satisfied: sympy in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from torch>=2.0.0->neuralforecast) (1.12)
# Requirement already satisfied: networkx in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from torch>=2.0.0->neuralforecast) (3.2.1)
# Requirement already satisfied: jinja2 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from torch>=2.0.0->neuralforecast) (3.1.3)
# Collecting alembic>=1.5.0 (from optuna->neuralforecast)
#   Downloading alembic-1.13.1-py3-none-any.whl.metadata (7.4 kB)
# Collecting colorlog (from optuna->neuralforecast)
#   Downloading colorlog-6.8.2-py3-none-any.whl.metadata (10 kB)
# Collecting sqlalchemy>=1.3.0 (from optuna->neuralforecast)
#   Downloading SQLAlchemy-2.0.29-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.6 kB)
# Collecting Mako (from alembic>=1.5.0->optuna->neuralforecast)
#   Downloading Mako-1.3.2-py3-none-any.whl.metadata (2.9 kB)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->neuralforecast)
#   Downloading aiohttp-3.9.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.4 kB)
# Requirement already satisfied: setuptools in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from lightning-utilities>=0.8.0->pytorch-lightning>=2.0.0->neuralforecast) (69.1.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from packaging>=20.0->pytorch-lightning>=2.0.0->neuralforecast) (3.1.1)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas>=1.3.5->neuralforecast) (1.16.0)
# Collecting greenlet!=0.4.17 (from sqlalchemy>=1.3.0->optuna->neuralforecast)
#   Downloading greenlet-3.0.3-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from jinja2->torch>=2.0.0->neuralforecast) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from jsonschema->ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from jsonschema->ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from jsonschema->ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast) (0.33.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from jsonschema->ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast) (0.18.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from requests->ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from requests->ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from requests->ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from requests->ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from sympy->torch>=2.0.0->neuralforecast) (1.3.0)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->neuralforecast)
#   Downloading multidict-6.0.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->neuralforecast)
#   Downloading yarl-1.9.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (31 kB)
# Collecting async-timeout<5.0,>=4.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->neuralforecast)
#   Downloading async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# Downloading neuralforecast-1.7.0-py3-none-any.whl (199 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.0/199.0 kB 22.5 MB/s eta 0:00:00
# Downloading coreforecast-0.0.7-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (193 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.5/193.5 kB 3.2 MB/s eta 0:00:00ta 0:00:01
# Downloading pytorch_lightning-2.2.1-py3-none-any.whl (801 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 801.6/801.6 kB 22.0 MB/s eta 0:00:0000:01
# Downloading ray-2.10.0-cp310-cp310-manylinux2014_x86_64.whl (65.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.1/65.1 MB 9.7 MB/s eta 0:00:000:00:0100:01
# Downloading utilsforecast-0.1.2-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.1/40.1 kB 7.0 MB/s eta 0:00:00
# Downloading optuna-3.6.1-py3-none-any.whl (380 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 380.1/380.1 kB 55.6 MB/s eta 0:00:00
# Downloading alembic-1.13.1-py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.4/233.4 kB 37.9 MB/s eta 0:00:00
# Downloading lightning_utilities-0.11.2-py3-none-any.whl (26 kB)
# Downloading msgpack-1.0.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (385 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 385.1/385.1 kB 47.8 MB/s eta 0:00:00
# Downloading SQLAlchemy-2.0.29-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 122.5 MB/s eta 0:00:00
# Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 15.1 MB/s eta 0:00:00
# Downloading torchmetrics-1.3.2-py3-none-any.whl (841 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 841.5/841.5 kB 68.5 MB/s eta 0:00:00
# Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Downloading frozenlist-1.4.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (239 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.5/239.5 kB 36.3 MB/s eta 0:00:00
# Downloading colorlog-6.8.2-py3-none-any.whl (11 kB)
# Downloading aiohttp-3.9.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 22.7 MB/s eta 0:00:00:00:01
# Downloading greenlet-3.0.3-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (616 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 616.0/616.0 kB 18.5 MB/s eta 0:00:00
# Downloading Mako-1.3.2-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 15.0 MB/s eta 0:00:00
# Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Downloading multidict-6.0.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (124 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.3/124.3 kB 4.5 MB/s eta 0:00:00
# Downloading yarl-1.9.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (301 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.6/301.6 kB 43.9 MB/s eta 0:00:00
# Installing collected packages: multidict, msgpack, Mako, greenlet, frozenlist, coreforecast, colorlog, async-timeout, yarl, tensorboardX, sqlalchemy, lightning-utilities, aiosignal, utilsforecast, torchmetrics, alembic, aiohttp, ray, optuna, pytorch-lightning, neuralforecast
# Successfully installed Mako-1.3.2 aiohttp-3.9.3 aiosignal-1.3.1 alembic-1.13.1 async-timeout-4.0.3 colorlog-6.8.2 coreforecast-0.0.7 frozenlist-1.4.1 greenlet-3.0.3 lightning-utilities-0.11.2 msgpack-1.0.8 multidict-6.0.5 neuralforecast-1.7.0 optuna-3.6.1 pytorch-lightning-2.2.1 ray-2.10.0 sqlalchemy-2.0.29 tensorboardX-2.6.2.2 torchmetrics-1.3.2 utilsforecast-0.1.2 yarl-1.9.4

# %% [markdown]
# # Model Training

# %%
from neuralforecast import NeuralForecast
from neuralforecast.models import LSTM, NHITS, RNN

horizon = 48

# Try different hyperparmeters to improve accuracy.
models = [LSTM(h=horizon,                    # Forecast horizon
               max_steps=200,                # Number of steps to train
               scaler_type='standard',       # Type of scaler to normalize data
               encoder_hidden_size=32,       # Defines the size of the hidden state of the LSTM
               decoder_hidden_size=32,),     # Defines the number of hidden units of each layer of the MLP decoder
          NHITS(h=horizon,                   # Forecast horizon
                input_size=horizon,      # Length of input sequence
                max_steps=50,               # Number of steps to train
                n_freq_downsample=[2, 1, 1]) # Downsampling factors for each stack output
          ]
nf = NeuralForecast(models=models, freq='h')
# Out:
# Seed set to 1
# Seed set to 1

# %%
# %%time
nf.fit(df)
# Out:
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# CPU times: user 32.2 s, sys: 985 ms, total: 33.2 s
# Wall time: 59.1 s

# %%
# import torch
# torch.cuda.empty_cache()

# %%
# import gc
# del variables
# gc.collect()

# %%
# print(torch.cuda.memory_summary(device=None, abbreviated=True))

# %% [markdown]
# # Prediction

# %%
df_hat = nf.predict()
# Out:
# Predicting: |          | 0/? [00:00<?, ?it/s]
# Predicting: |          | 0/? [00:00<?, ?it/s]

# %%
df_hat.reset_index(inplace=True)
df_hat.head()
# Out:
#    unique_id                  ds        LSTM       NHITS
# 0          0 2023-06-01 00:00:00  537.161804  512.904175
# 1          0 2023-06-01 01:00:00  424.805878  510.907562
# 2          0 2023-06-01 02:00:00  415.020782  491.876892
# 3          0 2023-06-01 03:00:00  377.705597  485.201843
# 4          0 2023-06-01 04:00:00  322.458832  445.163025

# %% [markdown]
# # Save model

# %%
nf.save(path='./checkpoints/test_run/',
        model_index=None, 
        overwrite=True,
        save_dataset=True)

# %% [markdown]
# # Load model

# %%
from neuralforecast import NeuralForecast

nf2 = NeuralForecast.load(path='./checkpoints/test_run/')
df_hat2 = nf2.predict().reset_index()
df_hat2.head()
# Out:
# Seed set to 1
# Seed set to 1
# Predicting: |          | 0/? [00:00<?, ?it/s]
# Predicting: |          | 0/? [00:00<?, ?it/s]
#    unique_id                  ds        LSTM       NHITS
# 0          0 2023-06-01 00:00:00  537.161804  512.904175
# 1          0 2023-06-01 01:00:00  424.805878  510.907562
# 2          0 2023-06-01 02:00:00  415.020782  491.876892
# 3          0 2023-06-01 03:00:00  377.705597  485.201843
# 4          0 2023-06-01 04:00:00  322.458832  445.163025

# %%
df_hat2 == df_hat
# Out:
#       unique_id    ds  LSTM  NHITS
# 0          True  True  True   True
# 1          True  True  True   True
# 2          True  True  True   True
# 3          True  True  True   True
# 4          True  True  True   True
# ...         ...   ...   ...    ...
# 3307       True  True  True   True
# 3308       True  True  True   True
# 3309       True  True  True   True
# 3310       True  True  True   True
# 3311       True  True  True   True
#
# [3312 rows x 4 columns]

# %% [markdown]
# # Plot predictions

# %%
# df_hat.to_csv("data/df_hat.csv", index=False)

# %%
df_hat = pd.read_csv("data/df_hat.csv")
df_hat.head()
# Out:
#    unique_id                   ds       LSTM      NHITS
# 0          0  2023-06-01 00:00:00  537.16180  512.90420
# 1          0  2023-06-01 01:00:00  424.80588  510.90756
# 2          0  2023-06-01 02:00:00  415.02078  491.87690
# 3          0  2023-06-01 03:00:00  377.70560  485.20184
# 4          0  2023-06-01 04:00:00  322.45883  445.16302

# %%
# !pip install utilsforecast
# Out:
# Collecting utilsforecast
#   Downloading utilsforecast-0.1.2-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from utilsforecast) (1.26.4)
# Requirement already satisfied: packaging in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from utilsforecast) (21.3)
# Requirement already satisfied: pandas>=1.1.1 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from utilsforecast) (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from pandas>=1.1.1->utilsforecast) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from pandas>=1.1.1->utilsforecast) (2024.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from packaging->utilsforecast) (3.1.1)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas>=1.1.1->utilsforecast) (1.16.0)
# Downloading utilsforecast-0.1.2-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.1/40.1 kB 5.8 MB/s eta 0:00:00
# Installing collected packages: utilsforecast
# Successfully installed utilsforecast-0.1.2

# %%
import random
import pandas as pd
import matplotlib.pyplot as plt
random.seed(0)

plot_id = random.randint(0, len(df["unique_id"].unique()))
fig, ax = plt.subplots(figsize=(12, 4))
# Concatenate the end of train and forecast dataframes
df_end = df[-(df_hat.shape[0]):]
plot_df = pd.concat([df_end[df_end["unique_id"]==plot_id], df_hat[df_hat["unique_id"]==plot_id]]).set_index('ds')
plot_df[['y', 'LSTM', 'NHITS']].plot(ax=ax, linewidth=2)
ax.set_title('Consumption Forecast')
ax.set_ylabel('Consumption')
ax.set_xlabel('Datetime')
ax.legend()
ax.grid()

# %%
from utilsforecast.plotting import plot_series

# taking the last 72 hours for plotting
for i in df["unique_id"].unique():
    if i == df["unique_id"].unique()[0]:
        last_72 = df[df["unique_id"]==i][-72:]
        continue
    last_72 = pd.concat([df_test, df[df["unique_id"]==i][-72:]])
    
last_72.sort_index(inplace=True)

plot_series(last_72, df_hat, max_ids=4, plot_random=False)
